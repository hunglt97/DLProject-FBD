# %%
import os
os.chdir('/content/drive/MyDrive/DLProject/Nghia')

# %%
import numpy as np
import pandas as pd
import cv2

# %%
import utils

# %%
(x_train, y_train), (x_test, y_test) = utils.get_data('../SCUT-FBP5500_v2/')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-28842add486e> in <module>()
# ----> 1 (x_train, y_train), (x_test, y_test) = utils.get_data('../SCUT-FBP5500_v2/')
#
# /content/drive/MyDrive/DLProject/Nghia/utils.py in get_data(data_path)
#      10     x_test = []
#      11     for i in range(len(data_test[0])):
# ---> 12         x_test.append(cv2.imread(f'{img_path}/{data_test[0][i]}')[:,:,::-1])
#      13     x_test = np.array(x_test)
#      14     y_test = np.array(data_test[1])
#
# KeyboardInterrupt:

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)

# %%
np.save('x_train', x_train)
np.save('y_train', y_train)
np.save('x_test', x_test)
np.save('y_test', y_test)
